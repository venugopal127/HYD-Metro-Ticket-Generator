# %%
import datetime as dt 
def result(r,g,b,s):
    for num in r:
        if(num==s):
            return "s1"
            break
    for num in b:
        if(num==s):
            return "s3" 
            break
    for num in g:
        if(num==s):
            return "s2" 
            break
def index(r,g,b,s):
    for num in r:
        if(num==s):
            l= r.index(num)
            return l
            break
    for num in b:
        if(num==s):
            l= b.index(num)
            return l
            break
    for num in g:
        if(num==s):
            l= g.index(num)
            return l
            break
def stations():
    print("\t\t\t\t\t\tHYDERABAD METRO RAIL\n")
    print("Choose your source and destination station\n RED LINE :\t\t\t\tGREEN LINE:\t\t\t\tBLUE LINE:\n 1 LB Nagar \t\t\t\t28 parade ground \t\t\t36 Nagole\n 2 victoria Memorial\t\t\t29 secundrabad west \t\t\t37 uppal\n 3 Chaitanyapuri \t\t\t30 gandhi Hospital \t\t\t38 stadium\n 4 Dilshuknagar \t\t\t31 musheerabad bad \t\t\t39 NGRI\n 5 Musarambagh \t\t\t\t32 rtc x road \t\t\t\t40 Habsiguda\n 6 New Market \t\t\t\t33 chikkadpally \t\t\t41 Tarnaka\n 7 Malakpate \t\t\t\t34 narayanaguda \t\t\t42 Metuguda\n 8 MG Bus station \t\t\t35 sultan bajar \t\t\t43 Secundrabad east\n 9 Osmania Medical College \t\t\t\t\t\t\t44 Paradise\n10 Gandhi Bhavan \t\t\t\t\t\t\t\t45 rasoolpura\n11 Nampally \t\t\t\t\t\t\t\t\t46 prakash nagar\n12 Assembly \t\t\t\t\t\t\t\t\t47 begumpet\n13 lakdi-ka-pul \t\t\t\t\t\t\t\t48 madhura nagar\n14 Khairatabad \t\t\t\t\t\t\t\t\t49 yusufguda\n15 Irrum Manzil \t\t\t\t\t\t\t\t50 road no 5 jubilee hilss\n16 Panjagutta \t\t\t\t\t\t\t\t\t51 jubilee hills checkpost\n17 Ameerpet \t\t\t\t\t\t\t\t\t52 peddamma gudi\n18 S.R.Nagar \t\t\t\t\t\t\t\t\t53 madhapur\n19 ESI Hospital \t\t\t\t\t\t\t\t54 durgam cheruvu\n20 Erragadda \t\t\t\t\t\t\t\t\t55 Hitec city\n21 Bharatnagar \t\t\t\t\t\t\t\t\t56 Raidurg\n22 Moosapet \n23 Dr.B.R.Ambedkar Balanagar \n24 Kukatpally \n25 KPHB Colony \n26 JNTU College \n27 Miyapur \n")
def station1(k,h):
    RED = [0,1.4,2.7,3.7,5.3,6.2,7.3,8.3,8.9,9.9,10.7,11.3,12.3,13.4,14.6,15.6,16.7,17.4,18.1,19.3,20.2,21.2,21.8,23.3,24.8,26.2,28.0]
    GREEN = [0,1.3,2.6,3.5,4.7,5.5,6.4,7.7]
    BLUE = [0,1,2.1,3.3,4.1,5.7,7,8.8,11.6,12.7,13.8,15.2,17.5,18.9,19.7,21,21.6,22.8,24.4,25.3,26.8]
    if(k=="s1"):
        return RED[h]
    elif(k=="s2"):
        return GREEN[h]
    elif(k=="s3"):
        return BLUE[h]
def station2(k,h):
    red = ["LB Nagar","victoria Memorial","Chaitanyapuri","Dilshuknagar","Musarambagh","New Market","Malakpate","MG Bus station","Osmania Medical College","Gandhi Bhavan","Nampally","Assembly","lakdi-ka-pul","Khairatabad","Irrum Manzil","Panjagutta","Ameerpet","S.R.Nagar","ESI Hospital","Erragadda","Bharatnag","Moosapet","Dr.B.R.Ambedkar","Kukatpally","KPHB Colony" ,"JNTU College","Miyapur "]
    green = ["parade ground","secundrabad east","gandhi Hospital","musheerabad","rtc x road","chikkadpally","narayanaguda","sultan bajar"]
    blue = ["Nagole","uppal","stadium","NGRI","Habsiguda","Tarnaka","Metuguda","Secundrabad east","Paradise","rasoolpura","prakash nagar","begumpet","madhura nagar","yusufguda","road no 5 jubilee hills","jubilee hills checkpost","peddamma gudi","madhapur","durgam cheruvu","Hitec city","Raidurg"]
    if(k=="s1"):
        return red[h]
    elif(k=="s2"):
        return green[h]
    elif(k=="s3"):
        return blue[h]
def distance(x,y,in1,in2):
        RED = [0, 1.4, 2.7, 3.7, 5.3, 6.2, 7.3, 8.3, 8.9, 9.9, 10.7, 11.3, 12.3, 13.4, 14.6, 15.6, 16.7, 17.4, 18.1, 19.3, 20.2, 21.2, 21.8, 23.3, 24.8, 26.2, 28.0]
        GREEN = [0, 1.3, 2.6, 3.5, 4.7, 5.5, 6.4, 7.7]
        BLUE = [0, 1, 2.1, 3.3, 4.1, 5.7, 7, 8.8, 11.6, 12.7, 13.8, 15.2, 17.5, 18.9, 19.7, 21, 21.6, 22.8, 24.4, 25.3, 26.8]

        if x=='s1':
            if y=='s1':
                return abs(RED[in1]-RED[in2])
            elif y=='s2':
                return abs(RED[7]-RED[in1])+abs(GREEN[in2]-GREEN[7])
            elif y=='s3':
                return abs(RED[16]-RED[in1])+abs(BLUE[in2]-BLUE[13])
        if x=='s2':
            if y=='s2':
                return abs(GREEN[in1]-GREEN[in2])
            elif y=='s1':
                return abs(RED[7]-RED[in1])+abs(GREEN[in2]-GREEN[7])
            elif y=='s3':
                return abs(GREEN[0]-GREEN[in1])+abs(BLUE[in2]-BLUE[8])
        if x=='s3':
            if y=='s3':
                return abs(BLUE[in1]-BLUE[in2])
            elif y=='s1':
                return abs(RED[16]-RED[in1])+abs(BLUE[in2]-BLUE[13])
            elif y=='s2':
                return abs(GREEN[0]-GREEN[in1])+abs(BLUE[in2]-BLUE[8])
def stops(RED,GREEN,BLUE,in1,in2):
    if x=='s1':
        
        if y=='s1':
                
            return abs(RED[in1]-RED[in2])
        elif y=='s2':
            return abs(RED[7]-RED[in1])+abs(GREEN[in2]-GREEN[7])
        elif y=='s3':
            return abs(RED[16]-RED[in1])+abs(BLUE[in2]-BLUE[13])
    if x=='s2':
        if y=='s2':
            return abs(GREEN[in1]-GREEN[in2])
        elif y=='s1':
            return abs(RED[7]-RED[in1])+abs(GREEN[in2]-GREEN[7])
        elif y=='s3':
            return abs(GREEN[0]-GREEN[in1])+abs(BLUE[in2]-BLUE[8])
    if x=='s3':
        if y=='s3':
            return abs(BLUE[in1]-BLUE[in2])
        elif y=='s1':
            return abs(RED[16]-RED[in1])+abs(BLUE[in2]-BLUE[13])
        elif y=='s2':
            return abs(GREEN[0]-GREEN[in1])+abs(BLUE[in2]-BLUE[8])
red = []
blue = []
green = []
for i in range(1,28):
    red.append(i)
for j in range(28,36):
    green.append(j)
for k in range(36,57):
    blue.append(k)
stations()
k = int(input("Enter the station number from:"))
g = int(input("Enter the station number to go:"))
p = int(input("enter the number of passangers:"))
x = result(red,green,blue,k)
y = result(red,green,blue,g)
in1 = index(red,green,blue,k)
in2 = index(red,green,blue,g)
n1 = station2(x,in1)
n2 = station2(y,in2)
q = station1(x,in1)
st=stops(red,green,blue,in1,in2)
w = station1(y,in2)
if((x=="s1" and y =="s1") or (x=="s2" and y =="s2") or (x=="s3" and y =="s3")):
    d =abs((w-q))
else:
    d1 =distance(x,y,in1,in2)
    d = d1 +(1.5)    
if(d>=16):
    r = int((d/2)*5)
else:   
    r = int((d/2)*5+10)
if(q > w):  
    r1 = int((w/2)*5+10)
elif(w >q):
    r1 = int((q/2)*5+10)
j = r%10
t = d*2
print("-------------------------------------------------------\n")
now = dt.datetime.now()
print("\t\t METRO DETAILS\n")
print(now.strftime(" %Y-%m-%d                          %H:%M:%S"))
print(" From :",n1)
print(" To   :",n2)
print(" Total number of passengers :",p)
print(" Total Distance(KM) :",format(d,".1f"))
print(" Travel time(mins)  :",format(t,".1f"))
print(" Total stops        :",st)
d1=format(d,".1f")
with open('tkt.txt','w') as f:
    f.write("-------------------------------------------\n")
    f.write(now.strftime(" %Y-%m-%d                     %H:%M:%S"))
    f.write(f"\nFrom : {n1}")
    f.write(f"\nTo   : {n2}")
    f.write(f"\nTotal number of passengers : {p}")
    f.write(f"\nTotal Distance(KM) : {d1}")
    f.write(f"\nTravel time(mins)  :{t}")
    f.write(f"\nTotal stops        :{st}")
    f.write(f"\nfare               : {format(10*p)} rupees")
    f.write("\n-------------------------------------------")
if(d<2):    
    print(" fare               : {} rupees".format(10*p))
if(r>60):
    r = r-r1
    j= r%10
if(d >2):
    if(j==0):
        r = r-j
        r = r*p
        print(" fare               : {} rupees".format(r))
    if(j>=1 and j<=6):
        r = r-j+5
        r = r*p
        print(" fare               : {} rupees".format(r))
    if(j>=7 and j<=10):
        r = r-j+10
        r = r*p
        print(" fare               : {} rupees".format(r))
if(x=="s1"):
    if(y=="s2"):
        print(" Change near Mg Bustation")
    elif(y=="s3"):
        print(" Change near Ammerpet")
elif(x=="s2"):
    if(y=="s1"):
        print(" Change Mg Bustation")
    elif(y=="s3"):
        print(" Change near Parade Ground")
elif(x=="s3"):
    if(y=="s1"):
        print(" Change near Ammerpet")
    elif(y=="s2"):
        print(" Change near Parade Ground")
print("-------------------------------------------------------\n")
import time
from plyer import notification as no
if __name__=="__main__":
    while True:
         no.notify(
             title = "METRO RAIL",
             message = "Thank you have a safe Journy.",
             timeout = 100
         ) 
         break
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display

image_path = 'hydmetro.png'
image = Image.open(image_path)

draw = ImageDraw.Draw(image)

font_path = 'arial.ttf' 
font_size = 20 

text = 'tkt.txt'
with open(text, 'r') as file:
    text_content = file.read()

font = ImageFont.truetype(font_path, size=font_size)

text_width, text_height = draw.textsize(text_content, font=font)

text_position = ((image.width - text_width) // 2, (image.height - text_height) // 2)

text_color = (0, 0, 0)  # Red color

draw.text(text_position, text_content, fill=text_color, font=font)

display(image)
# Out:
# 						HYDERABAD METRO RAIL
#
# Choose your source and destination station
#  RED LINE :				GREEN LINE:				BLUE LINE:
#  1 LB Nagar 				28 parade ground 			36 Nagole
#  2 victoria Memorial			29 secundrabad west 			37 uppal
#  3 Chaitanyapuri 			30 gandhi Hospital 			38 stadium
#  4 Dilshuknagar 			31 musheerabad bad 			39 NGRI
#  5 Musarambagh 				32 rtc x road 				40 Habsiguda
#  6 New Market 				33 chikkadpally 			41 Tarnaka
#  7 Malakpate 				34 narayanaguda 			42 Metuguda
#  8 MG Bus station 			35 sultan bajar 			43 Secundrabad east
#  9 Osmania Medical College 							44 Paradise
# 10 Gandhi Bhavan 								45 rasoolpura
# 11 Nampally 									46 prakash nagar
# 12 Assembly 									47 begumpet
# 13 lakdi-ka-pul 								48 madhura nagar
# 14 Khairatabad 									49 yusufguda
# 15 Irrum Manzil 								50 road no 5 jubilee hilss
# 16 Panjagutta 									51 jubilee hills checkpost
# 17 Ameerpet 									52 peddamma gudi
# 18 S.R.Nagar 									53 madhapur
# ...

# %% [markdown]
# ####
